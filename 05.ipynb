# %%
#Thêm thư viện 
from PIL import Image
from imgtools import *

# %%
#Đường dẫn ảnh
my_path = 'C:/Users/ACER/TGMT/src_cv/img/05/2.jpg'

# %%
#Đọc ảnh
img = load_image(my_path)
#Resize
#img = img.resize((250,250))

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=152x331>

# %%
#Xiay ảnh
rotated_image = img.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=152x331>

# %%
#Xoay ảnh
rotated_image = rotated_image.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=152x331>

# %%
#Transpose ảnh
transpose_image = img.transpose(Image.Transpose.ROTATE_90)
display(transpose_image)
# Out:
# <PIL.Image.Image image mode=RGB size=331x152>

# %%
#Transpose ảnh
transpose_image = transpose_image.transpose(Image.Transpose.ROTATE_90)
display(transpose_image)
# Out:
# <PIL.Image.Image image mode=RGB size=152x331>
