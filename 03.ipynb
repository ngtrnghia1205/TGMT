# %%
#Thêm thư viện 
from PIL import Image
from imgtools import *
from IPython.display import display #to display images

# %%
#Đường dẫn ảnh
my_path = 'C:/Users/ACER/TGMT/src_cv/img/03/1.jpg'

# %%
#Đọc ảnh
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=159x318>

# %%
#Kích thước ban đầu:
print(img.size)
# Out:
# (159, 318)

# %%
#Thay đổi kích thước:
new_size = (100,100)

# %%
#Tạo ảnh mới
new_image =img.resize(new_size)
display(new_image)
#Task: Lưu ảnh
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
#Thay đổi kích thước:
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
#Task: Lưu ảnh
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=25x50>
