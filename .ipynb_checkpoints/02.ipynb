# %%
#Dấu thăng dùng để ghi chú
#Shift + Enter : run đoạn code và thêm một dòng mới

# %%
#Ctrl+Enter : run đoạn code

# %%
#!pip install pillow

# %%
#Thêm thư viện 
from PIL import Image
from imgtools import *

# %%
#Khai báo một biến chứa thư mục(/ hoặc \\)
dir = 'C:/Users/ACER/TGMT/src_cv/img/02'

# %%
#Đọc nhiều ảnh
imgs = get_image_list(dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (159, 318)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=159x318>
# (152, 330)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=152x330>
# (159, 318)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=159x318>
# (168, 299)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=168x299>
# (168, 300)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=168x300>
